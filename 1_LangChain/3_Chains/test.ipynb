# %%
x = "The Indian Premier League (IPL) 2025 was the 18th edition of the tournament, with eight teams competing in a round-robin league followed by playoffs. Held in a bio-secure bubble due to COVID-19, the tournament featured star players like Virat Kohli and Rohit Sharma. Mumbai Indians emerged as champions, Virat Kohli retired from T20 cricket, Chris Gayle became the highest run-scorer, and Rashid Khan was the leading wicket-taker. With entertainment elements like virtual concerts and celebrity appearances, IPL 2025 was a successful event that showcased the best of T20 cricket"

# %%
x
# Out:
# 'The Indian Premier League (IPL) 2025 was the 18th edition of the tournament, with eight teams competing in a round-robin league followed by playoffs. Held in a bio-secure bubble due to COVID-19, the tournament featured star players like Virat Kohli and Rohit Sharma. Mumbai Indians emerged as champions, Virat Kohli retired from T20 cricket, Chris Gayle became the highest run-scorer, and Rashid Khan was the leading wicket-taker. With entertainment elements like virtual concerts and celebrity appearances, IPL 2025 was a successful event that showcased the best of T20 cricket'

# %%
print(len(x.split()))
# Out:
# 89

# %%
lambda x: len(x.split())>10000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for i in lambda x: len(x.split()):
#       2     print(i)
#
# TypeError: 'function' object is not iterable

# %%
print(result)
# Out:
# <function <lambda> at 0x000001DC02181300>
