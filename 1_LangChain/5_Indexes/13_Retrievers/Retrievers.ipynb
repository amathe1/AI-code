# %%
! pip install langchain chromadb faiss-cpu openai tiktoken langchain_openai langchain-community wikipedia
# Out:
# Requirement already satisfied: langchain in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (0.3.19)
# Requirement already satisfied: chromadb in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (0.6.3)
# Requirement already satisfied: faiss-cpu in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (1.10.0)
# Requirement already satisfied: openai in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (1.65.1)
# Requirement already satisfied: tiktoken in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (0.7.0)
# Requirement already satisfied: langchain_openai in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (0.2.14)
# Requirement already satisfied: langchain-community in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (0.3.18)
# Requirement already satisfied: wikipedia in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (1.4.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.35 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain) (0.3.40)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain) (0.3.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain) (0.1.147)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain) (2.10.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain) (3.11.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain) (2.2.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (0.115.6)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (3.18.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (0.21.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (1.71.0rc2)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (3.10.14)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from openai) (0.8.2)
# Requirement already satisfied: sniffio in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from wikipedia) (4.13.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: idna>=2.8 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: pyproject_hooks in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.41.3)
# Requirement already satisfied: certifi in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langchain-core<1.0.0,>=0.3.35->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: coloredlogs in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: sympy in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.68.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from opentelemetry-instrumentation==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.27.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from beautifulsoup4->wikipedia) (2.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.12.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.35->langchain) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\anilk\anaconda3\envs\venv-ak\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)

# %% [markdown]
# Wikipedia Retriever

# %%
from langchain_community.retrievers import WikipediaRetriever

# %%
# Initialize the retriever (optional: set language and top_k)
retriever = WikipediaRetriever(top_k_results=2, lang="en")

# %%
# Define your query
query = "the geopolitical history of india and pakistan from the perspective of a chinese"

# Get relevant Wikipedia documents
docs = retriever.invoke(query)

# %%
docs
# Out:
# [Document(metadata={'title': 'China–India relations', 'summary': "China and India maintained peaceful relations for thousands of years, but their relationship has varied since the Chinese Communist Party (CCP)'s victory in the Chinese Civil War in 1949 and the annexation of Tibet by the People's Republic of China. The two nations have sought economic cooperation with each other, while frequent border disputes and economic nationalism in both countries are major points of contention.\nCultural and economic relations between China and India date back to ancient times. The Silk Road not only served as a major trade route between India and China, but is also credited for facilitating the spread of Buddhism from India to East Asia. During the 19th century, China was involved in a growing opium trade with the East India Company, which exported opium grown in India. During World War II, both British India and the Republic of China (ROC) played a crucial role in halting the progress of Imperial Japan. After India became independent in 1947, it established relations with the ROC. The modern Sino
# Pakistan is a nuclear power as well as a declared nuclear-weapon state, having conducted six nuclear tests in response to five nuclear tests of their rival Republic of India in May 1998. The first five tests were conducted on 28 May and the sixth one on 30 May. With this status, Pakistan is seventh in world, second in South Asia and the only country in the Islamic World. Pakistan also has the sixth-largest standing armed forces in the world and is spending a major amount of its budget on defense. Pakistan is the founding member of the OIC, the SAARC and the Islamic Military Counter Terrorism Coalition as well as a member of many international organisations including the UN, the Shanghai Cooperation Organisation, the Commonwealth of Nations, the ARF, the Economic Cooperation Organization and many more.
# Pakistan is a middle power which is ranked among the emerging and growth-leading economies of the world and is backed by one of the world's largest and fastest-growing middle class. It has a semi-industrialized economy with a well-integrated agriculture sector. It is identified as one of the Next Eleven, a group of eleven countries that, along with the BRICs, have a high potential to become the world's largest economies in the 21st century. Although Pakistan faced a severe economic crisis from 2022 to 2024, geographically Pakistan is an important country and a source of contact between Middle East, Central Asia, South Asia and East Asia.
#
#
# == Pakistan Movement ==
#
# Important leaders in the Muslim League highlighted that Pakistan would be a "New Madinah", in other words the second Islamic state established after the Prophet Muhammad's creation of an Islamic state of Madinah which was later developed into Rashidun Caliphate. Pakistan was popularly envisaged as an Islamic utopia, a successor to the defunct Islamic Caliphate and a leader and protector of the entire Islamic world. Islamic scholars debated over whether it was possible for the proposed Pakistan to truly become an Islamic state.
# Another motive and reason behind the Pakistan Movement and Two Nation Theory is the ideology of pre-partition Muslims and leaders of Muslim League including Muhammad Ali Jinnah and Allama Iqbal is that, to re-establish the Muslim rule in South Asia. Once Jinnah said in his speech:
#
# The Pakistan Movement started when the first Muslim (Muhammad bin Qasim) put his foot on t...

# %% [markdown]
# Vector Store Retriever

# %%
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document

# %%
# Step 1: Your source documents
documents = [
    Document(page_content="LangChain helps developers build LLM applications easily."),
    Document(page_content="Chroma is a vector database optimized for LLM-based search."),
    Document(page_content="Embeddings convert text into high-dimensional vectors."),
    Document(page_content="OpenAI provides powerful embedding models."),
]

# %%
# Step 2: Initialize embedding model
embedding_model = OpenAIEmbeddings()

# Step 3: Create Chroma vector store in memory
vectorstore = Chroma.from_documents(
    documents=documents,
    embedding=embedding_model,
    collection_name="my_collection"
)

# %%
# Step 4: Convert vectorstore into a retriever
retriever = vectorstore.as_retriever(search_kwargs={"k": 2})

# %%
query = "What is Chroma used for?"
results = retriever.invoke(query)

# %%
for i, doc in enumerate(results):
    print(f"\n--- Result {i+1} ---")
    print(doc.page_content)
# Out:
# --- Result 1 ---
# Chroma is a vector database optimized for LLM-based search.
#
# --- Result 2 ---
# LangChain helps developers build LLM applications easily.

# %%
results = vectorstore.similarity_search(query, k=2)

# %%
for i, doc in enumerate(results):
    print(f"\n--- Result {i+1} ---")
    print(doc.page_content)
# Out:
# --- Result 1 ---
# Chroma is a vector database optimized for LLM-based search.
#
# --- Result 2 ---
# LangChain helps developers build LLM applications easily.

# %% [markdown]
# MMR (Maximal Marginal Relevance )

# %%
# Sample documents
docs = [
    Document(page_content="LangChain makes it easy to work with LLMs."),
    Document(page_content="LangChain is used to build LLM based applications."),
    Document(page_content="Chroma is used to store and search document embeddings."),
    Document(page_content="Embeddings are vector representations of text."),
    Document(page_content="MMR helps you get diverse results when doing similarity search."),
    Document(page_content="LangChain supports Chroma, FAISS, Pinecone, and more."),
]

# %%
from langchain_community.vectorstores import FAISS

# Initialize OpenAI embeddings
embedding_model = OpenAIEmbeddings()

# Step 2: Create the FAISS vector store from documents
vectorstore = FAISS.from_documents(
    documents=docs,
    embedding=embedding_model
)

# %%
# Enable MMR in the retriever
retriever = vectorstore.as_retriever(
    search_type="mmr",                   # <-- This enables MMR
    search_kwargs={"k": 3, "lambda_mult": 0.5}  # k = top results, lambda_mult = relevance-diversity balance
)

# %%
query = "What is langchain?"
results = retriever.invoke(query)

# %%
for i, doc in enumerate(results):
    print(f"\n--- Result {i+1} ---")
    print(doc.page_content)
# Out:
# --- Result 1 ---
# LangChain is used to build LLM based applications.
#
# --- Result 2 ---
# Embeddings are vector representations of text.
#
# --- Result 3 ---
# LangChain supports Chroma, FAISS, Pinecone, and more.

# %% [markdown]
# Multiquery Retriever

# %%
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document
from langchain_openai import ChatOpenAI
from langchain.retrievers.multi_query import MultiQueryRetriever

# %%
# Relevant health & wellness documents
all_docs = [
    Document(page_content="Regular walking boosts heart health and can reduce symptoms of depression.", metadata={"source": "H1"}),
    Document(page_content="Consuming leafy greens and fruits helps detox the body and improve longevity.", metadata={"source": "H2"}),
    Document(page_content="Deep sleep is crucial for cellular repair and emotional regulation.", metadata={"source": "H3"}),
    Document(page_content="Mindfulness and controlled breathing lower cortisol and improve mental clarity.", metadata={"source": "H4"}),
    Document(page_content="Drinking sufficient water throughout the day helps maintain metabolism and energy.", metadata={"source": "H5"}),
    Document(page_content="The solar energy system in modern homes helps balance electricity demand.", metadata={"source": "I1"}),
    Document(page_content="Python balances readability with power, making it a popular system design language.", metadata={"source": "I2"}),
    Document(page_content="Photosynthesis enables plants to produce energy by converting sunlight.", metadata={"source": "I3"}),
    Document(page_content="The 2022 FIFA World Cup was held in Qatar and drew global energy and excitement.", metadata={"source": "I4"}),
    Document(page_content="Black holes bend spacetime and store immense gravitational energy.", metadata={"source": "I5"}),
]

# %%
# Initialize OpenAI embeddings
embedding_model = OpenAIEmbeddings()

# Create FAISS vector store
vectorstore = FAISS.from_documents(documents=all_docs, embedding=embedding_model)

# %%
# Create retrievers
similarity_retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 5})

# %%
multiquery_retriever = MultiQueryRetriever.from_llm(
    retriever=vectorstore.as_retriever(search_kwargs={"k": 5}),
    llm=ChatOpenAI(model="gpt-3.5-turbo")
)

# %%
# Query
query = "How to improve energy levels and maintain balance?"

# %%
# Retrieve results
similarity_results = similarity_retriever.invoke(query)
multiquery_results= multiquery_retriever.invoke(query)

# %%
for i, doc in enumerate(similarity_results):
    print(f"\n--- Result {i+1} ---")
    print(doc.page_content)

print("*"*150)

for i, doc in enumerate(multiquery_results):
    print(f"\n--- Result {i+1} ---")
    print(doc.page_content)
# Out:
# --- Result 1 ---
# Drinking sufficient water throughout the day helps maintain metabolism and energy.
#
# --- Result 2 ---
# Mindfulness and controlled breathing lower cortisol and improve mental clarity.
#
# --- Result 3 ---
# Regular walking boosts heart health and can reduce symptoms of depression.
#
# --- Result 4 ---
# Deep sleep is crucial for cellular repair and emotional regulation.
#
# --- Result 5 ---
# Consuming leafy greens and fruits helps detox the body and improve longevity.
# ******************************************************************************************************************************************************
#
# --- Result 1 ---
# Drinking sufficient water throughout the day helps maintain metabolism and energy.
#
# --- Result 2 ---
# Deep sleep is crucial for cellular repair and emotional regulation.
#
# --- Result 3 ---
# Mindfulness and controlled breathing lower cortisol and improve mental clarity.
#
# --- Result 4 ---
# The solar energy system in modern homes helps balance electricity demand.
#
# --- Result 5 ---
# Regular walking boosts heart health and can reduce symptoms of depression.
#
# --- Result 6 ---
# Consuming leafy greens and fruits helps detox the body and improve longevity.

# %% [markdown]
# ContextualCompressionRetriever

# %%
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import LLMChainExtractor
from langchain_core.documents import Document

# %%
# Recreate the document objects from the previous data
docs = [
    Document(page_content=(
        """The Grand Canyon is one of the most visited natural wonders in the world.
        Photosynthesis is the process by which green plants convert sunlight into energy.
        Millions of tourists travel to see it every year. The rocks date back millions of years."""
    ), metadata={"source": "Doc1"}),

    Document(page_content=(
        """In medieval Europe, castles were built primarily for defense.
        The chlorophyll in plant cells captures sunlight during photosynthesis.
        Knights wore armor made of metal. Siege weapons were often used to breach castle walls."""
    ), metadata={"source": "Doc2"}),

    Document(page_content=(
        """Basketball was invented by Dr. James Naismith in the late 19th century.
        It was originally played with a soccer ball and peach baskets. NBA is now a global league."""
    ), metadata={"source": "Doc3"}),

    Document(page_content=(
        """The history of cinema began in the late 1800s. Silent films were the earliest form.
        Thomas Edison was among the pioneers. Photosynthesis does not occur in animal cells.
        Modern filmmaking involves complex CGI and sound design."""
    ), metadata={"source": "Doc4"})
]

# %%
# Create a FAISS vector store from the documents
embedding_model = OpenAIEmbeddings()
vectorstore = FAISS.from_documents(docs, embedding_model)

# %%
base_retriever = vectorstore.as_retriever(search_kwargs={"k": 5})

# %%
# Set up the compressor using an LLM
llm = ChatOpenAI(model="gpt-3.5-turbo")
compressor = LLMChainExtractor.from_llm(llm)

# %%
# Create the contextual compression retriever
compression_retriever = ContextualCompressionRetriever(
    base_retriever=base_retriever,
    base_compressor=compressor
)

# %%
# Query the retriever
query = "What is photosynthesis?"
compressed_results = compression_retriever.invoke(query)

# %%
for i, doc in enumerate(compressed_results):
    print(f"\n--- Result {i+1} ---")
    print(doc.page_content)
# Out:
# --- Result 1 ---
# Photosynthesis is the process by which green plants convert sunlight into energy.
#
# --- Result 2 ---
# The chlorophyll in plant cells captures sunlight during photosynthesis.
